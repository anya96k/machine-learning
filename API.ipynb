# %%
import requests
import numpy
import pandas as pd  
import json

API_key = 'c6fb64fec365de60c2e15986a29b3a1c'
lat = 18.520430
lon = 73.856743
url = f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_key}"

response = requests.get(url)
data = response.json()
print(json.dumps(data, indent=3))

weather_data = {
    'City': data.get('name'),
    'Country': data.get('sys', {}).get('country'),
    'Latitude': data.get('coord', {}).get('lat'),
    'Longitude': data.get('coord', {}).get('lon'),
    'Temperature (K)': data.get('main', {}).get('temp'),
    'Feels Like (K)': data.get('main', {}).get('feels_like'),
    'Weather Description': data.get('weather', [{}])[0].get('description'),
    'Humidity (%)': data.get('main', {}).get('humidity'),
    'Pressure (hPa)': data.get('main', {}).get('pressure'),
    'Wind Speed (m/s)': data.get('wind', {}).get('speed'),
    'Cloudiness (%)': data.get('clouds', {}).get('all')
}

df = pd.DataFrame([weather_data]) 
print(df)
# Out:
# {
#    "coord": {
#       "lon": 73.8567,
#       "lat": 18.5204
#    },
#    "weather": [
#       {
#          "id": 804,
#          "main": "Clouds",
#          "description": "overcast clouds",
#          "icon": "04d"
#       }
#    ],
#    "base": "stations",
#    "main": {
#       "temp": 304.54,
#       "feels_like": 310.86,
#       "temp_min": 304.54,
#       "temp_max": 305.42,
#       "pressure": 1007,
#       "humidity": 67,
#       "sea_level": 1007,
#       "grnd_level": 946
#    },
#    "visibility": 10000,
#    "wind": {
#       "speed": 1.87,
#       "deg": 108,
#       "gust": 2.18
#    },
#    "clouds": {
#       "all": 99
#    },
#    "dt": 1724222408,
#    "sys": {
#       "type": 2,
#       "id": 2091523,
#       "country": "IN",
#       "sunrise": 1724201274,
#       "sunset": 1724246871
#    },
#    "timezone": 19800,
#    "id": 1259229,
#    "name": "Pune",
#    "cod": 200
# }
#    City Country  Latitude  Longitude  Temperature (K)  Feels Like (K)  \
# 0  Pune      IN   18.5204    73.8567           304.54          310.86
#
#   Weather Description  Humidity (%)  Pressure (hPa)  Wind Speed (m/s)  \
# 0     overcast clouds            67            1007              1.87
#
#    Cloudiness (%)
# 0              99
